# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN,KMeans

# %%
X,_=make_blobs(n_samples=500,centers=4,cluster_std=0.60,random_state=0)

# %%
#Apply DBSCAN
dbscan=DBSCAN(eps=0.3,min_samples=5)
dbscan_labels=dbscan.fit_predict(X)

# %%
#Apply kmeans
kmeans=KMeans(n_clusters=4)
kmeans_labels=kmeans.fit_predict(X)
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
#plotting the clusters
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,6))
#DBSCAN plot
ax1.scatter(X[:,0],X[:,1],c=dbscan_labels,cmap='plasma')
ax1.set_title("DBSCAN Clustering")
ax1.set_xlabel('Feature 1')
ax1.set_ylabel('Feature 2')
#Kmeans plot
ax2.scatter(X[:,0],X[:,1],c=kmeans_labels,cmap='plasma')
ax2.set_title("Kmeans Clustering")
ax2.set_xlabel('Feature 1')
ax2.set_ylabel('Feature 2')
plt.tight_layout()
plt.show()
