# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\CVR\Documents\ml1.csv")

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  20 non-null     int64
#  1   height  20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes
#          weight     height
# count  20.00000   20.00000
# mean   49.50000  159.50000
# std     5.91608    5.91608
# min    40.00000  150.00000
# 25%    44.75000  154.75000
# 50%    49.50000  159.50000
# 75%    54.25000  164.25000
# max    59.00000  169.00000

# %%
print(df.isnull().sum())
# Out:
# weight    0
# height    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['height'], kde=True, bins=10, color='green')
plt.title('Distribution of Height')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
df.head()
# Out:
#    weight  height
# 0      40     150
# 1      41     151
# 2      42     152
# 3      43     153
# 4      44     154

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='height', y='weight', data=df)
plt.title('Scatter Plot of Weight vs Height')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
df
# Out:
#     weight  height
# 0       40     150
# 1       41     151
# 2       42     152
# 3       43     153
# 4       44     154
# 5       45     155
# 6       46     156
# 7       47     157
# 8       48     158
# 9       49     159
# 10      50     160
# 11      51     161
# 12      52     162
# 13      53     163
# 14      54     164
# 15      55     165
# 16      56     166
# 17      57     167
# 18      58     168
# 19      59     169

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['weight'], kde=True, bins=10, color='blue')
plt.title('Histogram of Weight')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()

# %%
df.corr()
# Out:
#         weight  height
# weight     1.0     1.0
# height     1.0     1.0

# %%
plt.scatter(df['weight'], df['height'])
plt.xlabel("Weight (kg)")
plt.ylabel("Height (cm)")
plt.title("Scatter Plot of Weight vs Height")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='seaborn')
sns.pairplot(df)
plt.show()

# %%
x=df[['weight']]
y=df[['height']]
type(x)
type(y)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ***Train test split***

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state=42)
df = pd.DataFrame(df)
x_train.shape
# Out:
# (15, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(x_train)
# Out:
# array([[-0.94254133],
#        [ 0.20379272],
#        [-1.32465269],
#        [ 1.54118245],
#        [ 1.1590711 ],
#        [ 0.58590407],
#        [-1.51570836],
#        [-0.17831863],
#        [ 1.73223813],
#        [-1.13359701],
#        [ 0.3948484 ],
#        [-0.56042998],
#        [ 0.01273705],
#        [ 0.77695975],
#        [-0.75148566]])

# %%
x_test=scaler.transform(x_test)
print(x_test)
# Out:
# [[-9.90263597]
#  [-9.28209736]
#  [-9.3551019 ]
#  [-9.8661337 ]
#  [-9.6106178 ]]

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression(n_jobs=-1)
regression.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
#print coefficient and intercept
print("Coefficient or slope",regression.coef_)
print("Intercept",regression.intercept_)
# Out:
# Coefficient or slope [1.]
# Intercept 110.00000000000003

# %%
## plot Training data plot best fit line
scatter = plt.scatter(x_train,y_train)
plt.show(scatter)

# %%
slope_of_best_fit = plt.plot(x_train,regression.predict(x_train))
