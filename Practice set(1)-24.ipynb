# %%
import pandas as pd
import numpy as np

# %%
cd
# Out:
# C:\Users\Proxy1

# %%
import pandas as pd
hd=pd.read_csv(r"C:\Users\Proxy1\Downloads\Casino_Gaming_Data new.csv")
hd.head()  #first five  rows data
# Out:
#   Fiscal Year            Month Ending                             Licensee  \
# 0     2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1     2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2     2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3     2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4     2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0     379023           335505                 5
# 1     671843           685886                 3
# 2  420056291        406814933            164727
# 3  254393582        246515856             11645
# 4     716607           681306                 0
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            43513
# 1                           -14046
# 2                         13076631
# 3                          7866081
# 4                            35301
#
# ...

# %%
hd.tail()  #last 5 columns in dataset
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
#         Wagers  Patron Winnings  Cancelled Wagers  \
# 138  552906853        532307920            468730
# 139    3543119          3410769               132
# 140    3199509          3072580               265
# 141  692210181        668971512            697914
# 142  535796500        516077716            561709
#
#      Online Casino Gaming Win/(Loss)  \
# 138                         20130203
# 139                           132219
# 140                           126663
# 141                         22540755
# ...

# %%
hd.info()  #information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Fiscal Year                                 143 non-null    object
#  1   Month Ending                                143 non-null    object
#  2   Licensee                                    143 non-null    object
#  3   Wagers                                      143 non-null    int64
#  4   Patron Winnings                             143 non-null    int64
#  5   Cancelled Wagers                            143 non-null    int64
#  6   Online Casino Gaming Win/(Loss)             143 non-null    int64
#  7   Promotional Coupons or Credits Wagered (3)  143 non-null    int64
#  8   Promotional Deduction (4)                   143 non-null    int64
#  9   Total Gross Gaming Revenue                  143 non-null    int64
# ...

# %%
hd.shape  # No.of columns and rows
# Out:
# (143, 11)

# %%
hd.columns  # all columns
# Out:
# Index(['Fiscal Year', 'Month Ending', 'Licensee', 'Wagers', 'Patron Winnings',
#        'Cancelled Wagers', 'Online Casino Gaming Win/(Loss)',
#        'Promotional Coupons or Credits Wagered (3)',
#        'Promotional Deduction (4)', 'Total Gross Gaming Revenue',
#        'Payment (5)'],
#       dtype='object')

# %%
hd.isnull().sum()  #checking for null values
# Out:
# Fiscal Year                                   0
# Month Ending                                  0
# Licensee                                      0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %%
hd[['Fiscal Year']]
# Out:
#     Fiscal Year
# 0       2021/22
# 1       2021/22
# 2       2021/22
# 3       2021/22
# 4       2021/22
# ..          ...
# 138     2024/25
# 139     2024/25
# 140     2024/25
# 141     2024/25
# 142     2024/25
#
# [143 rows x 1 columns]

# %%
hd['Wagers'].unique() #unique values in paricular column
# Out:
# array([   379023,    671843, 420056291, 254393582,    716607,    710829,
#        496904669, 275818534,   1464737, 475988357, 283107499,   2398475,
#        537888829, 280620004,    824365, 493591525, 249479067,    440462,
#        502522740, 277089825,    114528, 523770709, 290977291, 416047836,
#        275235600, 189562887, 123299057,    951394,   1349642, 561270181,
#        416060480,    825564,    938279, 585774812, 426356807,   1104372,
#          1146472, 573153012, 418771696,    823620,    698145, 627058607,
#        460910874,    853749,    970920, 545658135, 397870713,    841903,
#           579262, 541102178, 382071941,   1029050,    944718, 592670553,
#        408351893,    376858,    727476, 512129835, 390511890,    861503,
#          1120026, 589795481, 383984265,    943397,   2402069, 588426934,
#        351739905,    486688,   2960102, 449551138, 398913099,    482704,
#          1155448, 439413278, 265653958,   2210706,   2831236, 708771431,
# ...

# %%
hd['Wagers'].nunique() # no.of unique values in a particular column
# Out:
# 143

# %%
hd.drop_duplicates()       #removing duplicates
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 0       2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1       2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2       2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3       2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4       2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# ..          ...                     ...                                  ...
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
# ...

# %%
hd.describe()
# Out:
#              Wagers  Patron Winnings  Cancelled Wagers  \
# count  1.430000e+02     1.430000e+02      1.430000e+02
# mean   2.742207e+08     2.655218e+08      1.783408e+05
# std    2.815530e+08     2.725166e+08      2.826004e+05
# min    1.145280e+05     1.113650e+05      0.000000e+00
# 25%    1.407190e+06     1.357855e+06      5.000000e+00
# 50%    2.656540e+08     2.575127e+08      3.887000e+03
# 75%    5.352846e+08     5.156584e+08      2.913700e+05
# max    7.838842e+08     7.573176e+08      1.133136e+06
#
#        Online Casino Gaming Win/(Loss)  \
# count                     1.430000e+02
# mean                      8.520509e+06
# std                       8.921912e+06
# min                      -8.099000e+04
# 25%                       3.713950e+04
# 50%                       7.866081e+06
# 75%                       1.587461e+07
# max                       2.570443e+07
#
#        Promotional Coupons or Credits Wagered (3)  Promotional Deduction (4)  \
# ...

# %%
hd.rename(columns={'Payment (5)':'TotalAmount'}) #renaming column
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 0       2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1       2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2       2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3       2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4       2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# ..          ...                     ...                                  ...
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
# ...

# %%
hd['Wagers'].mean()
# Out:
# 274220672.5874126

# %%
hd['Wagers'].median()
# Out:
# 265653958.0

# %%
hd['Wagers'].mode()
# Out:
# 0         114528
# 1         376858
# 2         379023
# 3         440462
# 4         482704
#          ...
# 138    760237364
# 139    764459406
# 140    766255540
# 141    769608621
# 142    783884226
# Name: Wagers, Length: 143, dtype: int64

# %%
hd['Wagers'].std()
# Out:
# 281553025.83681095

# %%
hd['Fiscal Year'] = hd['Fiscal Year'].str.split('/').str[0].astype(int)
hd['Fiscal Year'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: Fiscal Year, dtype: int32

# %%
hd.isnull().sum()
# Out:
# Fiscal Year                                   0
# Month Ending                                  0
# Licensee                                      0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %%
hd.isnull().sum()
# Out:
# Fiscal Year                                   0
# Month Ending                                  0
# Licensee                                      0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %%
import pandas as pd
hd=pd.read_csv(r"C:\Users\Proxy1\Downloads\Casino_Gaming_Data new.csv")
hd.isnull().sum()
# Out:
# Fiscal Year                                   0
# Month Ending                                  0
# Licensee                                      0
# Wagers                                        1
# Patron Winnings                               1
# Cancelled Wagers                              1
# Online Casino Gaming Win/(Loss)               2
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     5
# Total Gross Gaming Revenue                    0
# Payment (5)                                   6
# dtype: int64

# %%
hd['Promotional Deduction (4)'].mean()
# Out:
# 1523633.3115942029

# %%
hd.fillna(hd['Promotional Deduction (4)'].mean())
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 0       2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1       2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2       2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3       2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4       2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# ..          ...                     ...                                  ...
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
# ...

# %%
hd.replace(0,hd['Promotional Deduction (4)'].mean())
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 0       2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1       2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2       2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3       2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4       2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# ..          ...                     ...                                  ...
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
# ...

# %%
hd.to_numpy()
# Out:
# array([['2021/22', '06/30/2022 12:00:00 AM',
#         'Mohegan Tribe On-Reservation', ..., 6390.0, 37123, 6682.0],
#        ['2021/22', '06/30/2022 12:00:00 AM', 'MPTN On-Reservation', ...,
#         nan, -14046, nan],
#        ['2021/22', '06/30/2022 12:00:00 AM',
#         'MPI Master Wagering License CT, LLC', ..., 3269158.0, 9807473,
#         1765345.0],
#        ...,
#        ['2024/25', '07/31/2024 12:00:00 AM', 'MPTN On-Reservation', ...,
#         15071.0, 111592, 20087.0],
#        ['2024/25', '07/31/2024 12:00:00 AM',
#         'MPI Master Wagering License CT, LLC', ..., 3381113.0, 19159642,
#         3448735.0],
#        ['2024/25', '07/31/2024 12:00:00 AM', 'Mohegan Digital, LLC', ...,
#         2873561.0, 16283514, 2931033.0]], dtype=object)

# %%
hd.T #Transposing your data
# Out:
#                                                                      0    \
# Fiscal Year                                                      2021/22
# Month Ending                                      06/30/2022 12:00:00 AM
# Licensee                                    Mohegan Tribe On-Reservation
# Wagers                                                          379023.0
# Patron Winnings                                                 335505.0
# Cancelled Wagers                                                     5.0
# Online Casino Gaming Win/(Loss)                                  43513.0
# Promotional Coupons or Credits Wagered (3)                          6390
# Promotional Deduction (4)                                         6390.0
# Total Gross Gaming Revenue                                         37123
# Payment (5)                                                       6682.0
#
#                                                                1    \
# ...

# %%
df.sort_index(axis=1, ascending=False)
